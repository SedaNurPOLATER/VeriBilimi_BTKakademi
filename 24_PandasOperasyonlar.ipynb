# %%
import pandas as pd
import numpy as np

# %%
sozlukVerisi = {"Istanbul" : [30,29,np.nan], "Ankara" : [20,np.nan,25], "Izmır" : [40,23,28]}
havaDurumuDataFrame = pd.DataFrame(sozlukVerisi)

# %%
havaDurumuDataFrame
# Out:
#    Istanbul  Ankara  Izmır
# 0      30.0    20.0     40
# 1      29.0     NaN     23
# 2       NaN    25.0     28

# %%
havaDurumuDataFrame.dropna()
# Out:
#    Istanbul  Ankara  Izmır
# 0      30.0    20.0     40

# %%
havaDurumuDataFrame
# Out:
#    Istanbul  Ankara  Izmır
# 0      30.0    20.0     40
# 1      29.0     NaN     23
# 2       NaN    25.0     28

# %%
havaDurumuDataFrame.dropna(axis = 1)
# Out:
#    Izmır
# 0     40
# 1     23
# 2     28

# %%
yeniVeri = {"Istanbul" : [30,29,np.nan], "Ankara" : [20,np.nan,25], "Izmir" : [40,39,38], "Antalya":[45,np.nan,np.nan]}
yeniDataFrame = pd.DataFrame(yeniVeri)

# %%
yeniDataFrame
# Out:
#    Istanbul  Ankara  Izmir  Antalya
# 0      30.0    20.0     40     45.0
# 1      29.0     NaN     39      NaN
# 2       NaN    25.0     38      NaN

# %%
yeniDataFrame.fillna(20)
# Out:
#    Istanbul  Ankara  Izmir  Antalya
# 0      30.0    20.0     40     45.0
# 1      29.0    20.0     39     20.0
# 2      20.0    25.0     38     20.0

# %% [markdown]
# ## groupby

# %%
maasSozlugu = {"Departman" : ["Yazılım" , "Satış", "Pazarlama", "Finans", "İnsan Kaynakları", "Hukuk"],
              "Calisan Ismi" : ["Ahmet", "Mehmet", "Atil", "Burak", "Zeynep", "Fatma"],
               "Maas" : [100,150,200,300,400,500]
              }

# %%
maasDataFrame = pd.DataFrame(maasSozlugu)

# %%
maasDataFrame
# Out:
#           Departman Calisan Ismi  Maas
# 0           Yazılım        Ahmet   100
# 1             Satış       Mehmet   150
# 2         Pazarlama         Atil   200
# 3            Finans        Burak   300
# 4  İnsan Kaynakları       Zeynep   400
# 5             Hukuk        Fatma   500

# %%
grupObjesi = maasDataFrame.groupby("Departman")

# %%
grupObjesi.count()
# Out:
#                   Calisan Ismi  Maas
# Departman
# Finans                       1     1
# Hukuk                        1     1
# Pazarlama                    1     1
# Satış                        1     1
# Yazılım                      1     1
# İnsan Kaynakları             1     1

# %%
grupObjesi.mean()
# Out:
#                    Maas
# Departman
# Finans            300.0
# Hukuk             500.0
# Pazarlama         200.0
# Satış             150.0
# Yazılım           100.0
# İnsan Kaynakları  400.0

# %%
grupObjesi.max()
# Out:
#                  Calisan Ismi  Maas
# Departman
# Finans                  Burak   300
# Hukuk                   Fatma   500
# Pazarlama                Atil   200
# Satış                  Mehmet   150
# Yazılım                 Ahmet   100
# İnsan Kaynakları       Zeynep   400

# %%
grupObjesi.describe()
# Out:
#                   Maas
#                  count   mean std    min    25%    50%    75%    max
# Departman
# Finans             1.0  300.0 NaN  300.0  300.0  300.0  300.0  300.0
# Hukuk              1.0  500.0 NaN  500.0  500.0  500.0  500.0  500.0
# Pazarlama          1.0  200.0 NaN  200.0  200.0  200.0  200.0  200.0
# Satış              1.0  150.0 NaN  150.0  150.0  150.0  150.0  150.0
# Yazılım            1.0  100.0 NaN  100.0  100.0  100.0  100.0  100.0
# İnsan Kaynakları   1.0  400.0 NaN  400.0  400.0  400.0  400.0  400.0
